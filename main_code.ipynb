# %%
# %pip install numpy 
# %pip install pandas
# %pip install seaborn 
# %pip install scikit-learn
# Out:
# Requirement already satisfied: numpy in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: six>=1.5 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\prith\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data Set

# %%
data=pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
x=data.drop(["median_house_value"],axis=1)
y=data["median_house_value"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
train_data=x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15022    -117.00     32.77                30.0       1802.0           401.0
# 16092    -122.50     37.76                52.0       2018.0           422.0
# 17736    -121.80     37.31                21.0       2630.0           446.0
# 5848     -118.31     34.18                11.0       3112.0           890.0
# 11181    -117.95     33.83                31.0       2421.0           389.0
# ...          ...       ...                 ...          ...             ...
# 618      -122.15     37.73                45.0       3758.0           819.0
# 19088    -122.54     38.36                40.0       2725.0           531.0
# 14778    -117.09     32.58                12.0       2565.0           567.0
# 15747    -122.44     37.78                52.0       2911.0           753.0
# 5927     -117.80     34.10                17.0       5153.0          1164.0
#
#        population  households  median_income ocean_proximity  \
# 15022       776.0       386.0         2.8125       <1H OCEAN
# 16092      1142.0       463.0         3.7083      NEAR OCEAN
# 17736      1789.0       389.0         5.0543       <1H OCEAN
# 5848       1700.0       851.0         3.1587       <1H OCEAN
# 11181      1348.0       413.0         4.9394       <1H OCEAN
# ...           ...         ...            ...             ...
# 618        1573.0       736.0         2.8355        NEAR BAY
# 19088      1167.0       458.0         3.7969       <1H OCEAN
# 14778      1785.0       545.0         3.0273      NEAR OCEAN
# 15747      1696.0       676.0         2.5721        NEAR BAY
# 5927       2949.0      1083.0         3.5603          INLAND
#
#        median_house_value
# 15022            173500.0
# 16092            307700.0
# 17736            232000.0
# 5848             181300.0
# 11181            217800.0
# ...                   ...
# 618              245400.0
# 19088            202800.0
# 14778            135300.0
# 15747            475000.0
# 5927             174600.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,9))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
data = train_data.select_dtypes(include=['number'])
data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924426           -0.112193     0.048412
# latitude            -0.924426  1.000000            0.014535    -0.038350
# housing_median_age  -0.112193  0.014535            1.000000    -0.359307
# total_rooms          0.048412 -0.038350           -0.359307     1.000000
# total_bedrooms       0.071228 -0.067545           -0.318633     0.929315
# population           0.106448 -0.112074           -0.296460     0.857532
# households           0.059108 -0.073522           -0.300321     0.919184
# median_income       -0.015252 -0.081216           -0.110629     0.197693
# median_house_value  -0.049077 -0.143101            0.114388     0.130319
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071228    0.106448    0.059108      -0.015252
# latitude                 -0.067545   -0.112074   -0.073522      -0.081216
# housing_median_age       -0.318633   -0.296460   -0.300321      -0.110629
# total_rooms               0.929315    0.857532    0.919184       0.197693
# total_bedrooms            1.000000    0.876887    0.980398      -0.008919
# population                0.876887    1.000000    0.905472       0.005980
# households                0.980398    0.905472    1.000000       0.012509
# median_income            -0.008919    0.005980    0.012509       1.000000
# median_house_value        0.047432   -0.026324    0.063445       0.685845
#
#                     median_house_value
# longitude                    -0.049077
# latitude                     -0.143101
# housing_median_age            0.114388
# total_rooms                   0.130319
# total_bedrooms                0.047432
# population                   -0.026324
# households                    0.063445
# median_income                 0.685845
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
data = train_data.select_dtypes(include=['number'])
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
train_data['total_rooms']=np.log(train_data["total_rooms"]+1)
train_data['total_bedrooms']=np.log(train_data["total_bedrooms"]+1)
train_data["population"]=np.log(train_data["population"]+1)
train_data["households"]=np.log(train_data["households"]+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
if 'ocean_proximity' in train_data.columns:
    # Print the unique values and their counts
    print(train_data['ocean_proximity'].value_counts())
else:
    print("The 'ocean_proximity' column does not exist in the DataFrame.")
# Out:
# ocean_proximity
# <1H OCEAN     7213
# INLAND        5187
# NEAR OCEAN    2084
# NEAR BAY      1858
# ISLAND           4
# Name: count, dtype: int64

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7213
# INLAND        5187
# NEAR OCEAN    2084
# NEAR BAY      1858
# ISLAND           4
# Name: count, dtype: int64

# %%
train_data_ocean_proximity_encoded = pd.get_dummies(train_data.ocean_proximity)
train_data_ocean_proximity_encoded = train_data_ocean_proximity_encoded.astype(int)
train_data = train_data.join(train_data_ocean_proximity_encoded).drop(columns=['ocean_proximity'],axis=1)
print(train_data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15022    -117.00     32.77                30.0     7.497207        5.996452
# 16092    -122.50     37.76                52.0     7.610358        6.047372
# 17736    -121.80     37.31                21.0     7.875119        6.102559
# 5848     -118.31     34.18                11.0     8.043342        6.792344
# 11181    -117.95     33.83                31.0     7.792349        5.966147
# ...          ...       ...                 ...          ...             ...
# 618      -122.15     37.73                45.0     8.231908        6.709304
# 19088    -122.54     38.36                40.0     7.910591        6.276643
# 14778    -117.09     32.58                12.0     7.850104        6.342121
# 15747    -122.44     37.78                52.0     7.976595        6.625392
# 5927     -117.80     34.10                17.0     8.547528        7.060476
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 15022    6.655440    5.958425         2.8125            173500.0          1
# 16092    7.041412    6.139885         3.7083            307700.0          0
# 17736    7.489971    5.966147         5.0543            232000.0          1
# 5848     7.438972    6.747587         3.1587            181300.0          1
# 11181    7.207119    6.025866         4.9394            217800.0          1
# ...           ...         ...            ...                 ...        ...
# 618      7.361375    6.602588         2.8355            245400.0          0
# 19088    7.063048    6.129050         3.7969            202800.0          1
# 14778    7.487734    6.302619         3.0273            135300.0          0
# 15747    7.436617    6.517671         2.5721            475000.0          0
# 5927     7.989560    6.988413         3.5603            174600.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 15022       0       0         0           0
# 16092       0       0         0           1
# 17736       0       0         0           0
# 5848        0       0         0           0
# 11181       0       0         0           0
# ...       ...     ...       ...         ...
# 618         0       0         1           0
# 19088       0       0         0           0
# 14778       0       0         0           1
# 15747       0       0         1           0
# 5927        1       0         0           0
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
data = train_data.select_dtypes(include=['number'])
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu")
plt.show()
